# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk import bigrams

nltk.download('stopwords')
sw = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
r = requests.get("https://www.gutenberg.org/cache/epub/73984/pg73984-images.html")

r.encoding = 'utf-8'

html = r.text

# %%
soup = BeautifulSoup(html, 'html.parser')

text = soup.get_text()

# %%
tokenizer = nltk.tokenize.RegexpTokenizer('\w+')

tokens = tokenizer.tokenize(text)

# %%
words = []

for word in tokens:
  words.append(word.lower())

# %%
words_ns =  [word for word in words if word not in sw]

# %%
freqdist = nltk.FreqDist(words_ns)

# %%
freqdist
# Out:
# FreqDist({'titanic': 631, 'boat': 528, 'ship': 515, 'one': 459, 'mrs': 447, 'said': 408, 'mr': 395, 'boats': 338, 'women': 329, 'men': 322, ...})

# %%
# %matplotlib inline

# %%
freqdist.plot(500)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
## BIGRAMA

# %%
string_bigrams = list(bigrams(words_ns))
print(string_bigrams)
# Out:
# [('project', 'gutenberg'), ('gutenberg', 'ebook'), ('ebook', 'sinking'), ('sinking', 'titanic'), ('titanic', 'jay'), ('jay', 'henry'), ('henry', 'mowbray'), ('mowbray', 'project'), ('project', 'gutenberg'), ('gutenberg', 'ebook'), ('ebook', 'sinking'), ('sinking', 'titanic'), ('titanic', 'appalling'), ('appalling', 'ocean'), ('ocean', 'horror'), ('horror', 'ebook'), ('ebook', 'use'), ('use', 'anyone'), ('anyone', 'anywhere'), ('anywhere', 'united'), ('united', 'states'), ('states', 'parts'), ('parts', 'world'), ('world', 'cost'), ('cost', 'almost'), ('almost', 'restrictions'), ('restrictions', 'whatsoever'), ('whatsoever', 'may'), ('may', 'copy'), ('copy', 'give'), ('give', 'away'), ('away', 'use'), ('use', 'terms'), ('terms', 'project'), ('project', 'gutenberg'), ('gutenberg', 'license'), ('license', 'included'), ('included', 'ebook'), ('ebook', 'online'), ('online', 'www'), ('www', 'gutenberg'), ('gutenberg', 'org'), ('org', 'located'), ('located', 'united'), ('united', 'states'), 
# ...

# %%
# %matplotlib inline
big = nltk.FreqDist(string_bigrams)

# %%
big.plot(500)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ---------------------------------------------------------------------
#
#
# 1. O livro segue a Lei de Zipf? Também considerando bigramas? Justifique.
#
# 2. As palavras mais frequentes de alguma forma estão relacionados com o enredo do livro?
#
#
#
# Sua Resposta:
#
# [LIVRO](https://www.gutenberg.org/cache/epub/73984/pg73984-images.html)
#
#
#
# 1. Sim, as palavra analisadas possui a sua frequência inversamente proporcional em sua ordem/rank como plotado no gráfico. O exemplo e gráfico deixa claro a sua frequência em relação a sua ordem/rank:
#
# {'titanic': 631, 'boat': 528, 'ship': 515, 'one': 459, 'mrs': 447, 'said': 408, 'mr': 395, 'boats': 338, 'women': 329, 'men': 322, ...}
#
# Também ocorre o efeito da cauda longa quando analisado como bigramas. Poderia ser realizado um processamento stop word, pois vemos que há palavras que poderiam ser removidas para uma melhor análise do texto, tais como gutenberg, ebook:
#
# ('project', 'gutenberg'), ('gutenberg', 'ebook'), ('ebook', 'sinking'), ('sinking', 'titanic'), ('titanic', 'jay'), ('jay', 'henry'), ('henry', 'mowbray')...
# 2. Sim, palavras tais como "titanic", "boat" e "ship" estão diretamente ligados ao enredo do livro, o qual a história se refere ao titanic e são frequentes no livro.
